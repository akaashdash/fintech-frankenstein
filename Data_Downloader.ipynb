# %% [markdown]
# Install dependencies

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %% [markdown]
# Imports

# %%
from datasets import load_dataset

# %% [markdown]
# Connect to drive
#
# Note: Before running this, add the VIP folder as a shortcut to your drive
#
# *Borrowed this from 4644 lol*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %load_ext autoreload
# %autoreload 2

import os
#change to desired path
os.chdir("./drive/MyDrive/VIP/router/data")
# %pwd
# Out:
# Mounted at /content/drive
# '/content/drive/.shortcut-targets-by-id/1UiU6uLtX7kvXdtuDnHtarlFc7ijUrMO6/VIP/router/data'

# %% [markdown]
# List of datasets from huggingface and the required columns

# %%
flare_datasets = [
    "ChanceFocus/flare-fpb",
    "ChanceFocus/flare-fiqasa",
    "ChanceFocus/flare-headlines",
    "ChanceFocus/flare-finqa",
    "ChanceFocus/flare-convfinqa",
    "ChanceFocus/flare-finer-ord",
    "ChanceFocus/flare-sm-bigdata",
    "ChanceFocus/flare-sm-acl",
    "ChanceFocus/flare-sm-cikm",
    "ChanceFocus/flare-german",
    "ChanceFocus/flare-australian",
    "ChanceFocus/flare-edtsum",
    "ChanceFocus/flare-fomc",
    "ChanceFocus/flare-ner"
]

# %% [markdown]
# Function to download dataset

# %%
def download_dataset(dataset_name, selected_columns):
    dataset = load_dataset(dataset_name)
    dataset.save_to_disk(dataset_name)
    print(f"Dataset {dataset_name} and saved to {dataset_name}")

# %% [markdown]
# Download all datasets

# %%
for dataset in flare_datasets:
    download_dataset(dataset, columns)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3100 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/970 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/776 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-fpb with selected columns downloaded and saved to ChanceFocus/flare-fpb
# Downloading readme:   0%|          | 0.00/633 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/100k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/35.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/29.9k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/750 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/235 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/188 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/750 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/235 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/188 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-fiqasa with selected columns downloaded and saved to ChanceFocus/flare-fiqasa
# Downloading readme:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/2.52M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/365k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/71892 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/20547 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/10269 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/71892 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/20547 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/10269 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-headlines with selected columns downloaded and saved to ChanceFocus/flare-headlines
# Downloading readme:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.18M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/6251 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1147 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/883 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/6251 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1147 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/883 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-finqa with selected columns downloaded and saved to ChanceFocus/flare-finqa
# Downloading readme:   0%|          | 0.00/622 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/8.35M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/8891 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1490 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/2213 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/8891 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1490 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2213 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-convfinqa with selected columns downloaded and saved to ChanceFocus/flare-convfinqa
# Downloading readme:   0%|          | 0.00/496 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/357k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/1075 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1075 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-finer-ord with selected columns downloaded and saved to ChanceFocus/flare-finer-ord
# Downloading readme:   0%|          | 0.00/654 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.78M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/433k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/4897 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1472 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/798 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4897 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1472 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/798 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-sm-bigdata with selected columns downloaded and saved to ChanceFocus/flare-sm-bigdata
# Downloading readme:   0%|          | 0.00/653 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/34.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.92M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.64M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/20781 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3720 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/2555 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/20781 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3720 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2555 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-sm-acl with selected columns downloaded and saved to ChanceFocus/flare-sm-acl
# Downloading readme:   0%|          | 0.00/651 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.15M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.70M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/3396 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1143 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/431 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3396 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1143 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/431 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-sm-cikm with selected columns downloaded and saved to ChanceFocus/flare-sm-cikm
# Downloading readme:   0%|          | 0.00/641 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/273k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/94.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/59.2k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/700 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/200 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/700 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/200 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-german with selected columns downloaded and saved to ChanceFocus/flare-german
# Downloading readme:   0%|          | 0.00/641 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/65.3k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/25.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.8k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/482 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/139 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/69 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/482 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/139 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/69 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-australian with selected columns downloaded and saved to ChanceFocus/flare-australian
# Downloading readme:   0%|          | 0.00/488 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/3.36M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/495 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/495 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-ectsum with selected columns downloaded and saved to ChanceFocus/flare-ectsum
# Downloading readme:   0%|          | 0.00/456 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/10.8M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-edtsum with selected columns downloaded and saved to ChanceFocus/flare-edtsum
# Downloading readme:   0%|          | 0.00/518 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/140k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/496 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/496 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-fomc with selected columns downloaded and saved to ChanceFocus/flare-fomc
# Downloading readme:   0%|          | 0.00/421 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/136k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/56.6k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/31.8k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/408 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/98 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/103 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/408 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/98 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/103 [00:00<?, ? examples/s]
# Dataset ChanceFocus/flare-ner with selected columns downloaded and saved to ChanceFocus/flare-ner
